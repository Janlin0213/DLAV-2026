# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchvision.datasets import CIFAR10

# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed=1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms for validation (no augmentation)
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # Define the transform for training (and data augmentation)

    train_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images if requested
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = next(data_iter)
        # Unnormalize the images for display
        mean = [0.4914, 0.4822, 0.4465]
        std = [0.2023, 0.1994, 0.2010]
        unnorm_images = [unnormalize(img, mean, std) for img in images]
        X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

def unnormalize(img, mean, std):
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

trainloader, valloader = get_train_valid_loader()
# Out:
# 100%|██████████| 170M/170M [00:01<00:00, 104MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].

# %% [markdown]
# # Convolutional Neural Network Architecture

# %% [markdown]
# Let's first talk about the overall architecture of a CNN and how each dimension evolves after each layer, we'll take as example the first and famous CNN LeNet5 :
# <figure align="center">
#   <img src="https://doimages.nyc3.cdn.digitaloceanspaces.com/010AI-ML/content/images/2021/10/image-17.png" alt="LeNet5 Architecture" width="600">
#   <figcaption>Image credit: <a href="https://en.wikipedia.org">Wikipedia</a></figcaption>
# </figure>

# %% [markdown]
# For that, we will have some quick questions to see if you understand what happens during training/inference:
#
# ### 1. First Layer Convolution
#
# If we consider the input of LeNet5 to be CIFAR-10, what would be the shape of the parameters of the first convolutional layer (stride = 1)?
#
# - **A.** `torch.Size([6, 1, 5, 5])`
# - **B.** `torch.Size([6, 3, 3, 3])`
# - **C.** `torch.Size([6, 1, 5, 5])`
# - **D.** **`torch.Size([6, 3, 5, 5])`** ***
#
# ---
#
# ### 2. Subsampling Window
#
# What is the shape of the subsampling window (stride = 2) for the second layer (between C1 and C2), and does this shape remain invariant regardless of the subsampling method (e.g., Avg pooling or Max pooling)?
#
# - **A.** **`2x2, yes it does`** ***
# - **B.** `3x3, no it doesn't`
# - **C.** `2x2, no it doesn't`
# - **D.** `yes, it does`
#
# ---
#
# ### 3. Backpropagation for Convolutional Filters
#
# Do the filters in the convolutional layers also benefit from backpropagation?
#
# ### *of course*
# ---
#
# ### 4. Role of the Fully-Connected Layer
#
# Explain in your own words why it is necessary to have a fully-connected layer in the architecture.
#
# ### *The fully connected layer is necessary to combine all extracted features from convolutional layers and perform the final classification. While convolutional layers learn local patterns, the fully connected layer integrates global information and maps it to class scores.*
# ---
#
# If you had any struggle to answer one of theses questions, feel free to ask a TA about intuition or hints about the solution.

# %% [markdown]
# # Build your own Convolutional Neural Network Architecture

# %% [markdown]
# ## Different ways to improve the accuracy of your network :
# - Change the number of convolutions and layers (you can take inspiration from internet as you as you cite the architecture)
# - Change the optmizer / its hyperparameters
# - Add new types of layers
# - Do some data augmentation in the get_train_valid_loader function (flipped, cropped, uncentered images) cf. https://pytorch.org/vision/stable/transforms.html

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################
        self.conv1 = nn.Conv2d(n_input_channels,16,kernel_size = 3, stride = 1, padding = 1)
        self.pool1 = nn.MaxPool2d(kernel_size = 2, stride = 2)
        self.conv2 = nn.Conv2d(16,32,kernel_size = 3, stride = 1, padding = 1)
        self.pool2 = nn.MaxPool2d(kernel_size = 2, stride = 2)
        self.fc1 = nn.Linear(32*8*8,120)
        self.fc2 = nn.Linear(120,n_output)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = x.view(x.size(0),-1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        return x

    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer1 = torch.optim.Adam(net.parameters(), lr=0.001, weight_decay=1e-4)

# net2 = ConvNet()
# optimizer2 = torch.optim.SGD(net2.parameters(), lr=0.003, momentum=0.9, weight_decay=1e-4)


epochs = 1
steps = 0
running_loss = 0
print_every = 20
best_acc = 0
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):

        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        targets = labels
        output = net(images)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, targets)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        optimizer1.zero_grad()
        loss.backward()
        optimizer1.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            net.eval()
            with torch.no_grad():
                for ii, (images, labels) in enumerate(valloader):
                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                      outputs = net(images)
                      _, predicted = torch.max(outputs, 1)
                      batch_accuracy = (predicted == labels).float().mean().item()
                      accuracy += batch_accuracy

            net.train()

            val_acc = accuracy / (ii + 1)

            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(net.state_dict(), "/content/drive/MyDrive/EPFL/DLAV_2026/graded_hw/best_cnn.pth")

                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################

            print("Epoch: {}/{}..".format(e+1, epochs),
                      "Loss: {:.4f}..".format(running_loss/print_every),
                      "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                      "{:.4f} s/batch".format((stop - start)/print_every)
                  )
            running_loss = 0
            start = time.time()
# Out:
# Epoch: 1/1.. Loss: 2.1949.. Test accuracy: 0.2361.. 0.1039 s/batch
# Epoch: 1/1.. Loss: 1.9900.. Test accuracy: 0.3090.. 0.0491 s/batch
# Epoch: 1/1.. Loss: 1.8688.. Test accuracy: 0.3613.. 0.0807 s/batch
# Epoch: 1/1.. Loss: 1.7618.. Test accuracy: 0.3805.. 0.0494 s/batch
# Epoch: 1/1.. Loss: 1.6604.. Test accuracy: 0.4266.. 0.0506 s/batch
# Epoch: 1/1.. Loss: 1.5852.. Test accuracy: 0.4621.. 0.0707 s/batch
# Epoch: 1/1.. Loss: 1.6205.. Test accuracy: 0.4533.. 0.0849 s/batch
# Epoch: 1/1.. Loss: 1.5394.. Test accuracy: 0.4613.. 0.0706 s/batch
# Epoch: 1/1.. Loss: 1.4680.. Test accuracy: 0.4410.. 0.0505 s/batch
# Epoch: 1/1.. Loss: 1.4010.. Test accuracy: 0.4584.. 0.0501 s/batch
# Epoch: 1/1.. Loss: 1.4565.. Test accuracy: 0.4816.. 0.0503 s/batch
# Epoch: 1/1.. Loss: 1.4151.. Test accuracy: 0.5063.. 0.0504 s/batch
# Epoch: 1/1.. Loss: 1.3945.. Test accuracy: 0.5260.. 0.0499 s/batch
# Epoch: 1/1.. Loss: 1.3517.. Test accuracy: 0.5160.. 0.0666 s/batch
# Epoch: 1/1.. Loss: 1.3469.. Test accuracy: 0.4963.. 0.0788 s/batch
# Epoch: 1/1.. Loss: 1.3105.. Test accuracy: 0.5211.. 0.0715 s/batch
# Epoch: 1/1.. Loss: 1.2879.. Test accuracy: 0.5057.. 0.0498 s/batch
# Epoch: 1/1.. Loss: 1.3191.. Test accuracy: 0.5363.. 0.0505 s/batch
# Epoch: 1/1.. Loss: 1.3050.. Test accuracy: 0.5199.. 0.0503 s/batch
# Epoch: 1/1.. Loss: 1.2983.. Test accuracy: 0.5270.. 0.0513 s/batch
# Epoch: 1/1.. Loss: 1.2294.. Test accuracy: 0.5434.. 0.0514 s/batch
# Epoch: 1/1.. Loss: 1.2175.. Test accuracy: 0.5426.. 0.0610 s/batch
# Epoch: 1/1.. Loss: 1.1979.. Test accuracy: 0.5434.. 0.0815 s/batch
# Epoch: 1/1.. Loss: 1.2384.. Test accuracy: 0.5256.. 0.0710 s/batch
# Epoch: 1/1.. Loss: 1.1987.. Test accuracy: 0.5506.. 0.0505 s/batch
# Epoch: 1/1.. Loss: 1.2680.. Test accuracy: 0.5568.. 0.0503 s/batch
# Epoch: 1/1.. Loss: 1.2658.. Test accuracy: 0.5506.. 0.0491 s/batch
# Epoch: 1/1.. Loss: 1.2317.. Test accuracy: 0.5590.. 0.0499 s/batch
# Epoch: 1/1.. Loss: 1.1897.. Test accuracy: 0.5561.. 0.0503 s/batch
# Epoch: 1/1.. Loss: 1.2268.. Test accuracy: 0.5793.. 0.0655 s/batch
# Epoch: 1/1.. Loss: 1.1882.. Test accuracy: 0.5459.. 0.0848 s/batch
# Epoch: 1/1.. Loss: 1.1917.. Test accuracy: 0.5746.. 0.0696 s/batch
# Epoch: 1/1.. Loss: 1.1890.. Test accuracy: 0.5814.. 0.0512 s/batch
# Epoch: 1/1.. Loss: 1.1223.. Test accuracy: 0.5738.. 0.0505 s/batch
# Epoch: 1/1.. Loss: 1.1662.. Test accuracy: 0.5871.. 0.0495 s/batch
# Epoch: 1/1.. Loss: 1.1607.. Test accuracy: 0.5750.. 0.0499 s/batch
# Epoch: 1/1.. Loss: 1.1869.. Test accuracy: 0.5984.. 0.0493 s/batch
# Epoch: 1/1.. Loss: 1.1976.. Test accuracy: 0.5764.. 0.0544 s/batch

# %%
# net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
# optimizer1 = torch.optim.Adam(net.parameters(), lr=0.001, weight_decay=1e-4)

net2 = ConvNet()
optimizer2 = torch.optim.SGD(net2.parameters(), lr=0.03, momentum=0.9, weight_decay=1e-4)


epochs = 5
steps = 0
running_loss = 0
print_every = 30
best_acc = 0
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):

        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        targets = labels
        output = net2(images)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, targets)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        optimizer2.zero_grad()
        loss.backward()
        optimizer2.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            net.eval()
            with torch.no_grad():
                for ii, (images, labels) in enumerate(valloader):
                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                      outputs = net(images)
                      _, predicted = torch.max(outputs, 1)
                      batch_accuracy = (predicted == labels).float().mean().item()
                      accuracy += batch_accuracy

            net.train()

            val_acc = accuracy / (ii + 1)

            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(net.state_dict(), "/content/drive/MyDrive/EPFL/DLAV_2026/graded_hw/best_cnn_sgd.pth")

                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################

            print("Epoch: {}/{}..".format(e+1, epochs),
                      "Loss: {:.4f}..".format(running_loss/print_every),
                      "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                      "{:.4f} s/batch".format((stop - start)/print_every)
                  )
            running_loss = 0
            start = time.time()
# Out:
# Epoch: 1/5.. Loss: 2.1648.. Test accuracy: 0.5775.. 0.0951 s/batch
# Epoch: 1/5.. Loss: 1.9272.. Test accuracy: 0.5752.. 0.0495 s/batch
# Epoch: 1/5.. Loss: 1.8246.. Test accuracy: 0.5758.. 0.0484 s/batch
# Epoch: 1/5.. Loss: 1.6753.. Test accuracy: 0.5770.. 0.0488 s/batch
# Epoch: 1/5.. Loss: 1.6319.. Test accuracy: 0.5734.. 0.0486 s/batch
# Epoch: 1/5.. Loss: 1.5547.. Test accuracy: 0.5781.. 0.0612 s/batch
# Epoch: 1/5.. Loss: 1.5512.. Test accuracy: 0.5752.. 0.0807 s/batch
# Epoch: 1/5.. Loss: 1.5563.. Test accuracy: 0.5781.. 0.0576 s/batch
# Epoch: 1/5.. Loss: 1.5184.. Test accuracy: 0.5793.. 0.0478 s/batch
# Epoch: 1/5.. Loss: 1.4746.. Test accuracy: 0.5758.. 0.0482 s/batch
# Epoch: 1/5.. Loss: 1.4351.. Test accuracy: 0.5770.. 0.0485 s/batch
# Epoch: 1/5.. Loss: 1.4353.. Test accuracy: 0.5764.. 0.0476 s/batch
# Epoch: 1/5.. Loss: 1.3823.. Test accuracy: 0.5770.. 0.0774 s/batch
# Epoch: 1/5.. Loss: 1.3806.. Test accuracy: 0.5805.. 0.0672 s/batch
# Epoch: 1/5.. Loss: 1.3794.. Test accuracy: 0.5758.. 0.0472 s/batch
# Epoch: 1/5.. Loss: 1.2906.. Test accuracy: 0.5787.. 0.0483 s/batch
# Epoch: 1/5.. Loss: 1.3736.. Test accuracy: 0.5764.. 0.0477 s/batch
# Epoch: 1/5.. Loss: 1.2283.. Test accuracy: 0.5740.. 0.0481 s/batch
# Epoch: 1/5.. Loss: 1.2920.. Test accuracy: 0.5758.. 0.0689 s/batch
# Epoch: 1/5.. Loss: 1.2407.. Test accuracy: 0.5764.. 0.0747 s/batch
# Epoch: 1/5.. Loss: 1.2480.. Test accuracy: 0.5793.. 0.0473 s/batch
# Epoch: 1/5.. Loss: 1.2620.. Test accuracy: 0.5729.. 0.0470 s/batch
# Epoch: 1/5.. Loss: 1.2420.. Test accuracy: 0.5799.. 0.0481 s/batch
# Epoch: 1/5.. Loss: 1.1924.. Test accuracy: 0.5752.. 0.0480 s/batch
# Epoch: 1/5.. Loss: 1.2553.. Test accuracy: 0.5752.. 0.0473 s/batch
# Epoch: 2/5.. Loss: 1.2447.. Test accuracy: 0.5770.. 0.0510 s/batch
# Epoch: 2/5.. Loss: 1.1047.. Test accuracy: 0.5775.. 0.0553 s/batch
# Epoch: 2/5.. Loss: 1.1717.. Test accuracy: 0.5758.. 0.0474 s/batch
# Epoch: 2/5.. Loss: 1.1939.. Test accuracy: 0.5770.. 0.0477 s/batch
# Epoch: 2/5.. Loss: 1.1421.. Test accuracy: 0.5746.. 0.0488 s/batch
# Epoch: 2/5.. Loss: 1.0994.. Test accuracy: 0.5781.. 0.0474 s/batch
# Epoch: 2/5.. Loss: 1.1651.. Test accuracy: 0.5746.. 0.0771 s/batch
# Epoch: 2/5.. Loss: 1.1898.. Test accuracy: 0.5770.. 0.0766 s/batch
# Epoch: 2/5.. Loss: 1.1477.. Test accuracy: 0.5764.. 0.0476 s/batch
# Epoch: 2/5.. Loss: 1.1438.. Test accuracy: 0.5781.. 0.0468 s/batch
# Epoch: 2/5.. Loss: 1.0925.. Test accuracy: 0.5775.. 0.0470 s/batch
# Epoch: 2/5.. Loss: 1.1082.. Test accuracy: 0.5770.. 0.0480 s/batch
# Epoch: 2/5.. Loss: 1.0598.. Test accuracy: 0.5775.. 0.0526 s/batch
# Epoch: 2/5.. Loss: 1.0778.. Test accuracy: 0.5775.. 0.0730 s/batch
# Epoch: 2/5.. Loss: 1.1033.. Test accuracy: 0.5764.. 0.0619 s/batch
# Epoch: 2/5.. Loss: 1.0967.. Test accuracy: 0.5758.. 0.0474 s/batch
# Epoch: 2/5.. Loss: 1.0565.. Test accuracy: 0.5752.. 0.0478 s/batch
# Epoch: 2/5.. Loss: 1.0566.. Test accuracy: 0.5746.. 0.0467 s/batch
# Epoch: 2/5.. Loss: 1.0568.. Test accuracy: 0.5799.. 0.0468 s/batch
# Epoch: 2/5.. Loss: 1.0922.. Test accuracy: 0.5775.. 0.0694 s/batch
# Epoch: 2/5.. Loss: 1.1397.. Test accuracy: 0.5764.. 0.0748 s/batch
# Epoch: 2/5.. Loss: 1.0584.. Test accuracy: 0.5758.. 0.0470 s/batch
# Epoch: 2/5.. Loss: 1.0132.. Test accuracy: 0.5781.. 0.0479 s/batch
# Epoch: 2/5.. Loss: 1.0652.. Test accuracy: 0.5770.. 0.0477 s/batch
# Epoch: 2/5.. Loss: 1.0557.. Test accuracy: 0.5787.. 0.0475 s/batch
# Epoch: 2/5.. Loss: 1.0753.. Test accuracy: 0.5781.. 0.0458 s/batch
# Epoch: 3/5.. Loss: 0.9780.. Test accuracy: 0.5781.. 0.1157 s/batch
# Epoch: 3/5.. Loss: 0.9354.. Test accuracy: 0.5746.. 0.0738 s/batch
# Epoch: 3/5.. Loss: 0.9759.. Test accuracy: 0.5752.. 0.0715 s/batch
# Epoch: 3/5.. Loss: 0.8952.. Test accuracy: 0.5770.. 0.0732 s/batch
# Epoch: 3/5.. Loss: 0.9102.. Test accuracy: 0.5758.. 0.0720 s/batch
# Epoch: 3/5.. Loss: 0.9894.. Test accuracy: 0.5740.. 0.0856 s/batch
# Epoch: 3/5.. Loss: 0.9617.. Test accuracy: 0.5770.. 0.0533 s/batch
# Epoch: 3/5.. Loss: 0.9985.. Test accuracy: 0.5764.. 0.0554 s/batch
# Epoch: 3/5.. Loss: 1.0017.. Test accuracy: 0.5787.. 0.0514 s/batch
# Epoch: 3/5.. Loss: 0.9520.. Test accuracy: 0.5758.. 0.0504 s/batch
# Epoch: 3/5.. Loss: 0.9538.. Test accuracy: 0.5764.. 0.0770 s/batch
# Epoch: 3/5.. Loss: 0.9544.. Test accuracy: 0.5775.. 0.0813 s/batch
# Epoch: 3/5.. Loss: 1.0289.. Test accuracy: 0.5793.. 0.0511 s/batch
# Epoch: 3/5.. Loss: 0.9632.. Test accuracy: 0.5729.. 0.0500 s/batch
# Epoch: 3/5.. Loss: 0.9921.. Test accuracy: 0.5805.. 0.0499 s/batch
# Epoch: 3/5.. Loss: 1.0117.. Test accuracy: 0.5770.. 0.0491 s/batch
# Epoch: 3/5.. Loss: 0.9914.. Test accuracy: 0.5787.. 0.0707 s/batch
# Epoch: 3/5.. Loss: 0.9448.. Test accuracy: 0.5793.. 0.0837 s/batch
# Epoch: 3/5.. Loss: 0.9249.. Test accuracy: 0.5770.. 0.0503 s/batch
# Epoch: 3/5.. Loss: 0.9303.. Test accuracy: 0.5764.. 0.0520 s/batch
# Epoch: 3/5.. Loss: 0.9667.. Test accuracy: 0.5793.. 0.0502 s/batch
# Epoch: 3/5.. Loss: 0.9398.. Test accuracy: 0.5764.. 0.0539 s/batch
# Epoch: 3/5.. Loss: 0.9130.. Test accuracy: 0.5764.. 0.0796 s/batch
# Epoch: 3/5.. Loss: 0.9358.. Test accuracy: 0.5781.. 0.0872 s/batch
# Epoch: 3/5.. Loss: 0.9704.. Test accuracy: 0.5752.. 0.0531 s/batch
# Epoch: 4/5.. Loss: 0.8378.. Test accuracy: 0.5793.. 0.0295 s/batch
# Epoch: 4/5.. Loss: 0.7765.. Test accuracy: 0.5775.. 0.0544 s/batch
# Epoch: 4/5.. Loss: 0.7712.. Test accuracy: 0.5770.. 0.0501 s/batch
# Epoch: 4/5.. Loss: 0.8235.. Test accuracy: 0.5781.. 0.0932 s/batch
# Epoch: 4/5.. Loss: 0.8246.. Test accuracy: 0.5752.. 0.0704 s/batch
# Epoch: 4/5.. Loss: 0.7963.. Test accuracy: 0.5764.. 0.0502 s/batch
# Epoch: 4/5.. Loss: 0.8048.. Test accuracy: 0.5764.. 0.0497 s/batch
# Epoch: 4/5.. Loss: 0.7891.. Test accuracy: 0.5781.. 0.0493 s/batch
# Epoch: 4/5.. Loss: 0.8532.. Test accuracy: 0.5793.. 0.0494 s/batch
# Epoch: 4/5.. Loss: 0.8354.. Test accuracy: 0.5799.. 0.0813 s/batch
# Epoch: 4/5.. Loss: 0.8586.. Test accuracy: 0.5781.. 0.0722 s/batch
# Epoch: 4/5.. Loss: 0.8879.. Test accuracy: 0.5781.. 0.0514 s/batch
# Epoch: 4/5.. Loss: 0.9100.. Test accuracy: 0.5770.. 0.0523 s/batch
# Epoch: 4/5.. Loss: 0.8907.. Test accuracy: 0.5781.. 0.0497 s/batch
# Epoch: 4/5.. Loss: 0.8810.. Test accuracy: 0.5781.. 0.0506 s/batch
# Epoch: 4/5.. Loss: 0.8746.. Test accuracy: 0.5764.. 0.0867 s/batch
# Epoch: 4/5.. Loss: 0.9220.. Test accuracy: 0.5781.. 0.0702 s/batch
# Epoch: 4/5.. Loss: 0.8560.. Test accuracy: 0.5793.. 0.0494 s/batch
# Epoch: 4/5.. Loss: 0.8543.. Test accuracy: 0.5770.. 0.0504 s/batch
# Epoch: 4/5.. Loss: 0.8543.. Test accuracy: 0.5764.. 0.0502 s/batch
# Epoch: 4/5.. Loss: 0.9550.. Test accuracy: 0.5752.. 0.0511 s/batch
# Epoch: 4/5.. Loss: 0.8936.. Test accuracy: 0.5805.. 0.0794 s/batch
# Epoch: 4/5.. Loss: 0.8749.. Test accuracy: 0.5746.. 0.0789 s/batch
# Epoch: 4/5.. Loss: 0.8935.. Test accuracy: 0.5764.. 0.0515 s/batch
# Epoch: 4/5.. Loss: 0.9378.. Test accuracy: 0.5758.. 0.0502 s/batch
# Epoch: 4/5.. Loss: 0.8698.. Test accuracy: 0.5770.. 0.0497 s/batch
# Epoch: 5/5.. Loss: 0.7171.. Test accuracy: 0.5758.. 0.0528 s/batch
# Epoch: 5/5.. Loss: 0.7365.. Test accuracy: 0.5770.. 0.0895 s/batch
# Epoch: 5/5.. Loss: 0.7592.. Test accuracy: 0.5781.. 0.0731 s/batch
# Epoch: 5/5.. Loss: 0.6796.. Test accuracy: 0.5723.. 0.0499 s/batch
# Epoch: 5/5.. Loss: 0.8020.. Test accuracy: 0.5770.. 0.0509 s/batch
# Epoch: 5/5.. Loss: 0.7709.. Test accuracy: 0.5781.. 0.0504 s/batch
# Epoch: 5/5.. Loss: 0.7584.. Test accuracy: 0.5775.. 0.0496 s/batch
# Epoch: 5/5.. Loss: 0.7174.. Test accuracy: 0.5770.. 0.0798 s/batch
# Epoch: 5/5.. Loss: 0.7567.. Test accuracy: 0.5770.. 0.0790 s/batch
# Epoch: 5/5.. Loss: 0.7406.. Test accuracy: 0.5787.. 0.0497 s/batch
# Epoch: 5/5.. Loss: 0.7704.. Test accuracy: 0.5775.. 0.0502 s/batch
# Epoch: 5/5.. Loss: 0.7533.. Test accuracy: 0.5752.. 0.0545 s/batch
# Epoch: 5/5.. Loss: 0.7430.. Test accuracy: 0.5787.. 0.0513 s/batch
# Epoch: 5/5.. Loss: 0.7614.. Test accuracy: 0.5781.. 0.0834 s/batch
# Epoch: 5/5.. Loss: 0.7601.. Test accuracy: 0.5717.. 0.0798 s/batch
# Epoch: 5/5.. Loss: 0.8251.. Test accuracy: 0.5758.. 0.0523 s/batch
# Epoch: 5/5.. Loss: 0.8067.. Test accuracy: 0.5775.. 0.0515 s/batch
# Epoch: 5/5.. Loss: 0.7781.. Test accuracy: 0.5793.. 0.0511 s/batch
# Epoch: 5/5.. Loss: 0.7742.. Test accuracy: 0.5793.. 0.0508 s/batch
# Epoch: 5/5.. Loss: 0.7970.. Test accuracy: 0.5752.. 0.0806 s/batch
# Epoch: 5/5.. Loss: 0.8286.. Test accuracy: 0.5781.. 0.0754 s/batch
# Epoch: 5/5.. Loss: 0.8804.. Test accuracy: 0.5764.. 0.0491 s/batch
# Epoch: 5/5.. Loss: 0.8479.. Test accuracy: 0.5752.. 0.0495 s/batch
# Epoch: 5/5.. Loss: 0.8362.. Test accuracy: 0.5781.. 0.0504 s/batch
# Epoch: 5/5.. Loss: 0.8942.. Test accuracy: 0.5764.. 0.0489 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)
## Saved

# %% [markdown]
# # Some visualisations and Interpretation questions
# This code allows us to look at the filters of the first layer of convolution :

# %%
def visualize_filters(layer, title='Filters'):
    filters = layer.weight.data.clone().cpu()
    filters = (filters - filters.min()) / (filters.max() - filters.min())
    grid = vutils.make_grid(filters, nrow=8, padding=2)
    plt.figure(figsize=(8,8))
    plt.imshow(grid.permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    plt.show()

model = ConvNet() # Untrained model

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# --- Untrained filters ---
# "features[0]" is your first convolutionnal layer, you might have to change it to conv1 if it was the name you gave it to
filters_untrained = model.conv1.weight.data.clone().cpu()
filters_untrained = (filters_untrained - filters_untrained.min()) / (filters_untrained.max() - filters_untrained.min())
grid_untrained = vutils.make_grid(filters_untrained, nrow=8, padding=2)
axes[0].imshow(grid_untrained.permute(1, 2, 0))
axes[0].set_title("Block 1 - First Conv Filters (Untrained)")
axes[0].axis("off")

# --- Trained filters ---
# Same thing here
filters_trained = net.conv1.weight.data.clone().cpu()
filters_trained = (filters_trained - filters_trained.min()) / (filters_trained.max() - filters_trained.min())
grid_trained = vutils.make_grid(filters_trained, nrow=8, padding=2)
axes[1].imshow(grid_trained.permute(1, 2, 0))
axes[1].set_title("Block 1 - First Conv Filters (Trained)")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What do you notice about the filters after the training ? Try to fin an interpretation about it.
# *I found the learned patterns are not clearly interpretable in the visualization. This is because each filter operates across three input channels (RGB), and the displayed colors correspond to the combination of weights in these channels rather than a direct visual pattern. As a result, the filters appear as colored patches rather than clear edge detectors. However, the trained filters are less random compared to the untrained ones, indicating that the network has learned meaningful low-level features. A more interpretable visualization maybe could be obtained by displaying each channel separately or converting filters to grayscale.*

# %%
filters = net.conv1.weight.detach().cpu()

for i in range(3):  # R,G,B
    grid = vutils.make_grid(filters[:, i:i+1, :, :], nrow=8)

    plt.imshow(grid[0], cmap='gray')
    plt.title(f'Channel {i}')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Activation maps
# This code snippet uses a forward hook to capture the output of the first convolutional layer of a CNN when a sample image is passed through it. The resulting activation maps show how each filter in the layer responds to different regions or features in the image.

# %%
def get_activation(model, layer, x):
    activation = {}
    def hook_fn(module, input, output):
        activation['output'] = output.detach().cpu()
    hook = layer.register_forward_hook(hook_fn)
    model(x)
    hook.remove()
    return activation['output']

data_iter = iter(trainloader)
sample_images, sample_labels = next(data_iter)
sample_img = sample_images[0].unsqueeze(0)

# Get the feature maps after the first convolution (for example)
activation = get_activation(net, net.conv1, sample_img)

# Visualize a few feature maps in RGB:
def plot_feature_maps(feature_maps, n_cols=8):
    n_features = feature_maps.shape[1]
    n_rows = (n_features + n_cols - 1) // n_cols
    plt.figure(figsize=(n_cols * 1.5, n_rows * 1.5))
    for i in range(n_features):
        plt.subplot(n_rows, n_cols, i + 1)
        # Extract the i-th feature map from the first (and only) sample in the batch
        act = feature_maps[0, i, :, :]
        # Normalize the activation map to [0, 1]
        act_norm = (act - act.min()) / (act.max() - act.min() + 1e-8)
        # Repeat the single channel 3 times to form an RGB image
        act_rgb = act_norm.unsqueeze(0).repeat(3, 1, 1)
        plt.imshow(act_rgb.permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_feature_maps(activation, n_cols=8)

# Play with the index of the chosen sample to notice more patterns and answer the question
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %% [markdown]
# ### 1. Feature Detection
# What specific features do you observe in these activation maps? Do some maps clearly highlight edges, contours, or textures? How might these features relate to the overall structure of the sample (e.g., the outline of a horse)?
#
# ### *The activation maps show that different filters respond to different low-level features of the image. Some feature maps clearly highlight edges and contours, Other feature maps respond to more distributed patterns, which may correspond to textures such as the ground or background variations. Noticeably, the activations are not limited to the car itself, as the first layer does not distinguish between foreground and background. It detects general visual patterns such as intensity changes and edges across the entire image. These low-level features form the basis for deeper layers, which will combine them into higher-level representations of objects. Same works for the boundaries of the horse, such as the legs and body outline. This indicates that the first convolutional layer is mostly detecting edge-like structures.*
# ---
#
# ### 2. Effect of Training
# Consider how the activations might change after training versus an untrained (random) network. What does this tell you about the learning process?
# ### *After training, the activation maps become more structured and meaningful compared to an untrained network. In an untrained network, the filters are randomly initialized, leading to activations that appear noisy and lack clear patterns. In contrast, after training, the filters become more selective and respond strongly to specific features such as edges and intensity changes. This results in activation maps where certain regions are highlighted more clearly, indicating that the network has learned to focus on informative patterns in the image. This demonstrates that the learning process enables the network to extract meaningful low-level features, which are essential for building higher-level representations in deeper layers.*
